# %% [markdown]
# # Introduction to PyTerrier
#
# _DSAIT4050: Information retrieval lecture, TU Delft_
#
# **Part 1: Setup**
#
# [Terrier](http://terrier.org) is an open-source information retrieval platform aimed at reserach and experimentation. We'll use [PyTerrier](https://pyterrier.readthedocs.io/), which provides a Python API for Terrier, in this lecture. This series of notebooks gives a brief introduction to PyTerrier.
#
# ## Installation
#
# PyTerrier can be installed using `pip`:

# %%
pip install python-terrier==0.12.1
# Out:
# Requirement already satisfied: python-terrier==0.12.1 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (0.12.1)
# Requirement already satisfied: numpy in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from python-terrier==0.12.1) (1.26.4)
# Requirement already satisfied: pandas in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from python-terrier==0.12.1) (2.3.3)
# Requirement already satisfied: more-itertools in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from python-terrier==0.12.1) (10.8.0)
# Requirement already satisfied: tqdm in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from python-terrier==0.12.1) (4.67.3)
# Requirement already satisfied: requests in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from python-terrier==0.12.1) (2.32.5)
# Requirement already satisfied: ir-datasets>=0.3.2 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from python-terrier==0.12.1) (0.5.11)
# Requirement already satisfied: wget in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from python-terrier==0.12.1) (3.2)
# Requirement already satisfied: pyjnius>=1.4.2 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from python-terrier==0.12.1) (1.7.0)
# Requirement already satisfied: deprecated in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from python-terrier==0.12.1) (1.3.1)
# Requirement already satisfied: scipy in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from python-terrier==0.12.1) (1.17.1)
# Requirement already satisfied: ir-measures>=0.3.1 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from python-terrier==0.12.1) (0.4.3)
# Requirement already satisfied: pytrec-eval-terrier>=0.5.3 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from python-terrier==0.12.1) (0.5.10)
# Requirement already satisfied: jinja2 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from python-terrier==0.12.1) (3.1.6)
# Requirement already satisfied: statsmodels in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from python-terrier==0.12.1) (0.14.6)
# Requirement already satisfied: dill in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from python-terrier==0.12.1) (0.4.1)
# Requirement already satisfied: joblib in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from python-terrier==0.12.1) (1.5.3)
# Requirement already satisfied: chest in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from python-terrier==0.12.1) (0.2.3)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from ir-datasets>=0.3.2->python-terrier==0.12.1) (4.14.3)
# Requirement already satisfied: inscriptis>=2.2.0 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from ir-datasets>=0.3.2->python-terrier==0.12.1) (2.7.1)
# Requirement already satisfied: lxml>=4.5.2 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from ir-datasets>=0.3.2->python-terrier==0.12.1) (6.0.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from ir-datasets>=0.3.2->python-terrier==0.12.1) (6.0.3)
# Requirement already satisfied: trec-car-tools>=2.5.4 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from ir-datasets>=0.3.2->python-terrier==0.12.1) (2.6)
# Requirement already satisfied: lz4>=3.1.10 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from ir-datasets>=0.3.2->python-terrier==0.12.1) (4.4.5)
# Requirement already satisfied: warc3-wet>=0.2.3 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from ir-datasets>=0.3.2->python-terrier==0.12.1) (0.2.5)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from ir-datasets>=0.3.2->python-terrier==0.12.1) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from ir-datasets>=0.3.2->python-terrier==0.12.1) (0.1.10)
# Requirement already satisfied: ijson>=3.1.3 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from ir-datasets>=0.3.2->python-terrier==0.12.1) (3.5.0)
# Requirement already satisfied: unlzw3>=0.2.1 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from ir-datasets>=0.3.2->python-terrier==0.12.1) (0.2.3)
# Requirement already satisfied: pyarrow>=16.1.0 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from ir-datasets>=0.3.2->python-terrier==0.12.1) (23.0.1)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from beautifulsoup4>=4.4.1->ir-datasets>=0.3.2->python-terrier==0.12.1) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from beautifulsoup4>=4.4.1->ir-datasets>=0.3.2->python-terrier==0.12.1) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from requests->python-terrier==0.12.1) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from requests->python-terrier==0.12.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from requests->python-terrier==0.12.1) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from requests->python-terrier==0.12.1) (2026.2.25)
# Requirement already satisfied: cbor>=1.0.0 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from trec-car-tools>=2.5.4->ir-datasets>=0.3.2->python-terrier==0.12.1) (1.0.0)
# Requirement already satisfied: heapdict in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from chest->python-terrier==0.12.1) (1.0.1)
# Requirement already satisfied: wrapt<3,>=1.10 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from deprecated->python-terrier==0.12.1) (2.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from jinja2->python-terrier==0.12.1) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from pandas->python-terrier==0.12.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from pandas->python-terrier==0.12.1) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from pandas->python-terrier==0.12.1) (2025.3)
# Requirement already satisfied: six>=1.5 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->python-terrier==0.12.1) (1.17.0)
# Requirement already satisfied: patsy>=0.5.6 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from statsmodels->python-terrier==0.12.1) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /Users/alexdespan/School/ms-information-retrieval/.venv/lib/python3.12/site-packages (from statsmodels->python-terrier==0.12.1) (26.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# You may want to consider using virtual environments, such as [`venv`](https://docs.python.org/3/library/venv.html) or [`conda`](https://www.anaconda.com/download). You'll also need an up-to-date version of the [Java development kit](https://www.oracle.com/java/technologies/downloads/) installed and the `JAVA_HOME` environment variable set. More detailed installation instructions and troubleshooting can be found [here](https://pyterrier.readthedocs.io/en/latest/installation.html).
#
# Now you should be able to import `pyterrier`:

# %%
import pyterrier as pt

# %% [markdown]
# ## A test run
#
# Time to test our setup! PyTerrier provides support for loading and indexing a large number of IR datasets (more on that later). Let's load the [ANTIQUE](https://arxiv.org/abs/1905.08957) dataset:

# %%
dataset = pt.get_dataset("irds:antique")

# %% [markdown]
# Now we can print one of the documents in the corpus:

# %%
from pprint import pprint

for doc in dataset.get_corpus_iter():
    pprint(doc)
    break
# Out:
# antique documents:   0%|          | 0/403666 [00:00<?, ?it/s]
# {'docno': '2020338_0',
#  'text': 'A small group of politicians believed strongly that the fact that '
#          'Saddam Hussien remained in power after the first Gulf War was a '
#          'signal of weakness to the rest of the world, one that invited '
#          'attacks and terrorism. Shortly after taking power with George Bush '
#          'in 2000 and after the attack on 9/11, they were able to use the '
#          'terrorist attacks to justify war with Iraq on this basis and '
#          'exaggerated threats of the development of weapons of mass '
#          'destruction. The military strength of the U.S. and the brutality of '
#          "Saddam's regime led them to imagine that the military and political "
#          'victory would be relatively easy.'}

# %% [markdown]
# If you see a document above now: Congratulations! The setup was successful. If not: Take a look at the [troubleshooting section](https://pyterrier.readthedocs.io/en/latest/installation.html#installation-troubleshooting) in the official documentation.
